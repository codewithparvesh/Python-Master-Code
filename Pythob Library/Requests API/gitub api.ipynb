# %%
import requests
import pandas as pd
from requests.auth import HTTPDigestAuth
r = requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos', auth=('codewithparvesh', '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'))
print(r.status_code)
print(r.url)
print()

d = r.json()
df = pd.DataFrame()
d
# Out:
# 200
# https://api.github.com/orgs/CodingNinjasCodes/repos
# [{'id': 68499062,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2ODQ5OTA2Mg==',
#   'name': 'SmoothScrollJs',
#   'full_name': 'CodingNinjasCodes/SmoothScrollJs',
#   'private': False,
#   'owner': {'login': 'CodingNinjasCodes',
#    'id': 22269960,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMjY5OTYw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22269960?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CodingNinjasCodes',
#    'html_url': 'https://github.com/CodingNinjasCodes',
#    'followers_url': 'https://api.github.com/users/CodingNinjasCodes/followers',
#    'following_url': 'https://api.github.com/users/CodingNinjasCodes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/CodingNinjasCodes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/CodingNinjasCodes/starred{/owner}{/repo}',
# ...

# %%
df[1][1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
for i in d:
    if (i['fork']== False):
        print(i['name'],i['watchers_count'],i['forks_count'])
# Out:
# SmoothScrollJs 16 7
# RubyTutorial 15 8
# Python3Tutorial 5 3
# HTMLandCssNotes 15 26
# Beacathon 2 7
# JSNotes 5 11
# learnml 1 0
# RubyNotebook 2 5
# InterQues 75 173
# coderoom 4 3
