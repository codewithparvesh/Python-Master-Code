# %%
import requests
import pandas as pd
from requests.auth import HTTPDigestAuth
r = requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos', auth=('codewithparvesh', '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'))
print(r.status_code)
print(r.url)
print()

d = r.json()
df = pd.DataFrame(d)
df
# Out:
# 200
# https://api.github.com/orgs/CodingNinjasCodes/repos
#            id                           node_id                name  \
# 0    68499062  MDEwOlJlcG9zaXRvcnk2ODQ5OTA2Mg==      SmoothScrollJs
# 1    69085681  MDEwOlJlcG9zaXRvcnk2OTA4NTY4MQ==        RubyTutorial
# 2    69153078  MDEwOlJlcG9zaXRvcnk2OTE1MzA3OA==     Python3Tutorial
# 3    77137953  MDEwOlJlcG9zaXRvcnk3NzEzNzk1Mw==     HTMLandCssNotes
# 4    77536043  MDEwOlJlcG9zaXRvcnk3NzUzNjA0Mw==           Beacathon
# 5    77905702  MDEwOlJlcG9zaXRvcnk3NzkwNTcwMg==             JSNotes
# 6    79562124  MDEwOlJlcG9zaXRvcnk3OTU2MjEyNA==             learnml
# 7    80911625  MDEwOlJlcG9zaXRvcnk4MDkxMTYyNQ==        RubyNotebook
# 8   164949973  MDEwOlJlcG9zaXRvcnkxNjQ5NDk5NzM=          matplotlib
# 9   238198546  MDEwOlJlcG9zaXRvcnkyMzgxOTg1NDY=           InterQues
# 10  238886111  MDEwOlJlcG9zaXRvcnkyMzg4ODYxMTE=  wall-of-developers
# 11  242716139  MDEwOlJlcG9zaXRvcnkyNDI3MTYxMzk=            coderoom
#
#                                full_name  private  \
# 0       CodingNinjasCodes/SmoothScrollJs    False
# 1         CodingNinjasCodes/RubyTutorial    False
# 2      CodingNinjasCodes/Python3Tutorial    False
# 3      CodingNinjasCodes/HTMLandCssNotes    False
# 4            CodingNinjasCodes/Beacathon    False
# 5              CodingNinjasCodes/JSNotes    False
# 6              CodingNinjasCodes/learnml    False
# 7         CodingNinjasCodes/RubyNotebook    False
# 8           CodingNinjasCodes/matplotlib    False
# 9            CodingNinjasCodes/InterQues    False
# 10  CodingNinjasCodes/wall-of-developers    False
# 11            CodingNinjasCodes/coderoom    False
#
#                                                 owner  \
# 0   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 1   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 2   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 3   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 4   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 5   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 6   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 7   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 8   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 9   {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 10  {'login': 'CodingNinjasCodes', 'id': 22269960,...
# 11  {'login': 'CodingNinjasCodes', 'id': 22269960,...
#
#                                              html_url  \
# 0   https://github.com/CodingNinjasCodes/SmoothScr...
# 1   https://github.com/CodingNinjasCodes/RubyTutorial
# 2   https://github.com/CodingNinjasCodes/Python3Tu...
# 3   https://github.com/CodingNinjasCodes/HTMLandCs...
# 4      https://github.com/CodingNinjasCodes/Beacathon
# 5        https://github.com/CodingNinjasCodes/JSNotes
# 6        https://github.com/CodingNinjasCodes/learnml
# 7   https://github.com/CodingNinjasCodes/RubyNotebook
# 8     https://github.com/CodingNinjasCodes/matplotlib
# 9      https://github.com/CodingNinjasCodes/InterQues
# 10  https://github.com/CodingNinjasCodes/wall-of-d...
# 11      https://github.com/CodingNinjasCodes/coderoom
#
#                                           description   fork  \
# 0              Smooth Scroll for all internal links.   False
# 1                                                None  False
# 2                                                None  False
# 3   Learn basic HTML and CSS using these notes, an...  False
# 4                                                None  False
# 5                                                None  False
# 6                                                None  False
# 7                                                None  False
# 8                    matplotlib: plotting with Python   True
# 9    Let's find the list of questions and collaborate  False
# 10  A place where students collaborate to create t...   True
# 11             A collaborative place for sharing code  False
#
#                                                   url  ... allow_forking  \
# 0   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 1   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 2   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 3   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 4   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 5   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 6   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 7   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 8   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 9   https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 10  https://api.github.com/repos/CodingNinjasCodes...  ...          True
# 11  https://api.github.com/repos/CodingNinjasCodes...  ...          True
#
#    is_template web_commit_signoff_required  \
# 0        False                       False
# 1        False                       False
# 2        False                       False
# 3        False                       False
# 4        False                       False
# 5        False                       False
# 6        False                       False
# 7        False                       False
# 8        False                       False
# 9        False                       False
# 10       False                       False
# 11       False                       False
#
#                                                topics visibility forks  \
# 0                                                  []     public     7
# 1                                                  []     public     8
# 2                                                  []     public     3
# 3                                                  []     public    26
# 4                                                  []     public     7
# 5                                                  []     public    11
# 6                                                  []     public     0
# 7                                                  []     public     5
# 8                                                  []     public     1
# 9   [css, html, interview-questions, javascript, p...     public   173
# 10                                                 []     public    66
# 11                                                 []     public     3
#
#    open_issues watchers default_branch  \
# 0            0       16         master
# 1            3       15         master
# 2            1        5         master
# 3            1       15         master
# 4            0        2         master
# 5            2        5         master
# 6            0        1         master
# 7            1        2         master
# 8            0        1         master
# 9           10       75    development
# 10           9       16    development
# 11           1        4    development
#
#                                           permissions
# 0   {'admin': False, 'maintain': False, 'push': Fa...
# 1   {'admin': False, 'maintain': False, 'push': Fa...
# 2   {'admin': False, 'maintain': False, 'push': Fa...
# 3   {'admin': False, 'maintain': False, 'push': Fa...
# 4   {'admin': False, 'maintain': False, 'push': Fa...
# 5   {'admin': False, 'maintain': False, 'push': Fa...
# 6   {'admin': False, 'maintain': False, 'push': Fa...
# 7   {'admin': False, 'maintain': False, 'push': Fa...
# 8   {'admin': False, 'maintain': False, 'push': Fa...
# 9   {'admin': False, 'maintain': False, 'push': Fa...
# 10  {'admin': False, 'maintain': False, 'push': Fa...
# 11  {'admin': False, 'maintain': False, 'push': Fa...
#
# [12 rows x 80 columns]

# %%
print
# Out:
#                                                      0
# 0    b'[{"id":68499062,"node_id":"MDEwOlJlcG9zaXRvc...
# 1    b'Js","private":false,"owner":{"login":"Coding...
# 2    b':"https://avatars.githubusercontent.com/u/22...
# 3    b'"html_url":"https://github.com/CodingNinjasC...
# 4    b'llowing_url":"https://api.github.com/users/C...
# ..                                                 ...
# 525  b'Script","has_issues":true,"has_projects":tru...
# 526  b'rks_count":3,"mirror_url":null,"archived":fa...
# 527  b'e","spdx_id":"MIT","url":"https://api.github...
# 528  b'false,"web_commit_signoff_required":false,"t...
# 529  b'ch":"development","permissions":{"admin":fal...
#
# [530 rows x 1 columns]

# %%
for i in d:
    if (i['fork']== False):
        print(i['name'],i['watchers_count'],i['forks_count'])
# Out:
# SmoothScrollJs 16 7
# RubyTutorial 15 8
# Python3Tutorial 5 3
# HTMLandCssNotes 15 26
# Beacathon 2 7
# JSNotes 5 11
# learnml 1 0
# RubyNotebook 2 5
# InterQues 75 173
# coderoom 4 3
