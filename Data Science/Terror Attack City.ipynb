# %% [markdown]
# Problem Statement :
#
# The Most Dangerous city in Jammu and Kashmir and the terrorist group which is most active in that city?
#
# Print count of number of attacks in that city as integer value.
#
# Note:Ignoring the Unknown Terrorist Group.Here Dangerous related with the number of terrorist attacks.
#
#
#
# ans >>> Srinagar 657 Muslim Separatists

# %%
import pandas as pd

# %%
df = pd.read_csv(r"data set\\terrorismData.csv")
df = df[df.State == 'Jammu and Kashmir']
city_count = df.City.value_counts()
c = city_count.index[0]
no = city_count[0]
df= df[df.City == c]
grp = df.Group.value_counts()
g = grp.index[1]
print(c,no, g)
# Out:
# Unknown                               306
# Muslim Separatists                     55
# Jammu and Kashmir Liberation Front     45
# Kashmiri extremists                    37
# Muslim Militants                       35
# Name: Group, dtype: int64
# Srinagar 657 Muslim Separatists

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# 0     1.0      0.0             Julio Guzman     NaN
# 1     0.0      0.0  Nadine Chaval, daughter     NaN
# 2     1.0      0.0                 Employee     NaN
# 3     NaN      NaN             U.S. Embassy     NaN
# 4     NaN      NaN           U.S. Consulate     NaN
#
#                                 Group                  Target_type Weapon_type
# 0                              MANO-D  Private Citizens & Property     Unknown
# 1  23rd of September Communist League      Government (Diplomatic)     Unknown
# 2                             Unknown          Journalists & Media     Unknown
# 3                             Unknown      Government (Diplomatic)  Explosives
# 4                             Unknown      Government (Diplomatic)  Incendiary

# %%
print(df.State.unique())
df.isnull().sum()
# Out:
# array([nan, 'Federal', 'Tarlac', ..., 'Carlow', 'Western Lakes',
#        'Vidzeme'], dtype=object)

# %%
df = df[df.State == 'Jammu and Kashmir']
df.head()
# Out:
#        Year  Month  Day Country              State      Region       City  \
# 21744  1984      4   17   India  Jammu and Kashmir  South Asia      Bhela
# 22108  1984      5   20   India  Jammu and Kashmir  South Asia      Jammu
# 29677  1986     12   11   India  Jammu and Kashmir  South Asia     Madora
# 33202  1988      1   21   India  Jammu and Kashmir  South Asia       Mand
# 33372  1988      2    7   India  Jammu and Kashmir  South Asia  Kherawali
#
#         Latitude  Longitude         AttackType  Killed  Wounded  \
# 21744  33.315527  74.622476      Assassination     2.0      0.0
# 22108  32.726602  74.857026  Bombing/Explosion     1.0      0.0
# 29677  33.934929  75.154160  Bombing/Explosion     1.0      5.0
# 33202  32.888165  74.985168      Armed Assault     2.0      0.0
# 33372  32.523889  74.974444      Armed Assault     4.0      5.0
#
#                                                Target Summary  \
# 21744  Gurbachan Singh Sandhar (Sikh lawyer) and wife     NaN
# 22108                            bridge over a stream     NaN
# 29677                     general post office complex     NaN
# 33202                                     police unit     NaN
# 33372                              marriage reception     NaN
#
#                  Group                  Target_type Weapon_type
# 21744  Sikh Extremists  Private Citizens & Property     Unknown
# 22108          Unknown               Transportation  Explosives
# 29677          Unknown         Government (General)     Unknown
# 33202          Unknown                       Police    Firearms
# 33372  Sikh Extremists  Private Citizens & Property    Firearms

# %%
city_count = df.City.value_counts()
print(city_count)
# Out:
# Srinagar     657
# Sopore       102
# Unknown       86
# Anantnag      76
# Jammu         57
#             ...
# Bragam         1
# Narsu          1
# Lasjan         1
# Goriwan        1
# Lethapora      1
# Name: City, Length: 633, dtype: int64

# %%
city = city_count.index[0]
no = city_count[0]
print(city, no)
# Out:
# Srinagar 657

# %%
df = df[df.City == city]
grp = df.Group.value_counts()
g = grp.index[1]
grp
# Out:
# Unknown                               306
# Muslim Separatists                     55
# Jammu and Kashmir Liberation Front     45
# Kashmiri extremists                    37
# Muslim Militants                       35
# Hizbul Mujahideen (HM)                 31
# Separatists                            21
# Lashkar-e-Taiba (LeT)                  21
# Jaish-e-Mohammad (JeM)                 12
# Al-Mansoorian                          12
# Sikh Extremists                         9
# Al-Umar Mujahideen                      8
# Jamiat ul-Mujahedin (JuM)               6
# Lashkar-e-Islam (India)                 4
# Al-Madina                               4
# Islamic Front                           3
# Muslim extremists                       3
# Tehrik al-Mojahedin                     3
# Al-Arifeen                              3
# Kashmiri Hezbollah                      3
# Jammu and Kashmir Islamic Front         2
# Ikhwan-ul-Muslimeen                     2
# Muslim Brotherhood                      2
# Muslim Janbaz Force                     2
# Mujahideen Kashmir                      2
# Allah's Tigers                          2
# Islamic Movement of Kashmir             2
# Al-Fajr                                 1
# Al-Badr                                 1
# Al-Nasireen Group                       1
# Al-Shuda Brigade                        1
# Save Kashmir Movement                   1
# Kashmir Freedom Force                   1
# Muslim Rebels                           1
# Al-Nasirin (India)                      1
# Harakat ul-Mujahidin (HuM)              1
# Gunmen                                  1
# Lashkar-e-Jhangvi                       1
# Al-Hamas Mujahideen                     1
# Militants                               1
# Pro-Pakistani extremists                1
# Ikhwan Jammu and Kashmir                1
# Dukhta-ran-e-Millat                     1
# Muslims                                 1
# Al-Jehad                                1
# Lashkari-e-Adam (Army of Adam)          1
# Al-Fatah                                1
# Achwan-I-Mushbani                       1
# Quit Kashmir Movement (QKM)             1
# Name: Group, dtype: int64

# %%
g
# Out:
# 'Muslim Separatists'

# %%
df.head()
# Out:
#        Year  Month  Day Country              State      Region      City  \
# 35266  1988      7   31   India  Jammu and Kashmir  South Asia  Srinagar
# 35267  1988      7   31   India  Jammu and Kashmir  South Asia  Srinagar
# 36073  1988     10   27   India  Jammu and Kashmir  South Asia  Srinagar
# 36074  1988     10   27   India  Jammu and Kashmir  South Asia  Srinagar
# 36078  1988     10   27   India  Jammu and Kashmir  South Asia  Srinagar
#
#        Latitude  Longitude         AttackType  Killed  Wounded  \
# 35266  34.08374  74.789902  Bombing/Explosion     0.0      0.0
# 35267  34.08374  74.789902  Bombing/Explosion     0.0      0.0
# 36073  34.08374  74.789902  Bombing/Explosion     0.0      9.0
# 36074  34.08374  74.789902  Bombing/Explosion     0.0      8.0
# 36078  34.08374  74.789902      Armed Assault     1.0      0.0
#
#                  Target Summary             Group  \
# 35266     Srinagar Club     NaN   Sikh Extremists
# 35267  Telegraph Office     NaN   Sikh Extremists
# 36073            Street     NaN           Unknown
# 36074       Police Unit     NaN  Muslim Militants
# 36078       Police Unit     NaN  Muslim Militants
#
#                        Target_type Weapon_type
# 35266  Private Citizens & Property  Explosives
# 35267                     Business  Explosives
# 36073  Private Citizens & Property  Explosives
# 36074                       Police  Explosives
# 36078                       Police    Firearms

# %%
df = pd.read_csv(r"data set\\terrorismData.csv")

# %% [markdown]
# There was formation of new government in India on 26 May 2014. So current government's span is from 26th May 2014 to current. Find out two things from this period-

# %%
df = df[(df.Country == 'India') & (df.Year >= 2014) & (df.Month >= 5)]
df
# Out:
#         Year  Month  Day Country              State      Region  \
# 132768  2014      6    1   India            Manipur  South Asia
# 132796  2014      6    1   India       Chhattisgarh  South Asia
# 132830  2014      6    2   India              Assam  South Asia
# 132873  2014      6    3   India       Chhattisgarh  South Asia
# 132879  2014      6    3   India          Jharkhand  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                      City   Latitude  Longitude  \
# 132768  Senapati district  25.273753  94.027276
# 132796   Bijapur district  18.846484  80.745099
# 132830           Jekabari  25.563479  89.890889
# 132873            Bijapur  18.797710  80.812864
# 132879    Khunti district  23.070000  85.280000
# ...                   ...        ...        ...
# 181663      Koothuparamba  11.831902  75.565432
# 181665           Toylanka  18.802725  81.497666
# 181672          Lethapora  33.966527  74.964225
# 181684            Hungrum  25.180162  93.015788
# 181689             Imphal  24.798346  93.940430
#
#                             AttackType  Killed  Wounded  \
# 132768     Hostage Taking (Kidnapping)     0.0      0.0
# 132796                   Armed Assault     1.0      0.0
# 132830     Hostage Taking (Kidnapping)     0.0      0.0
# 132873               Bombing/Explosion     0.0      0.0
# 132879                   Armed Assault     3.0      0.0
# ...                                ...     ...      ...
# 181663               Bombing/Explosion     0.0      0.0
# 181665  Facility/Infrastructure Attack     0.0      0.0
# 181672                   Armed Assault     8.0      3.0
# 181684     Hostage Taking (Kidnapping)     0.0      0.0
# 181689               Bombing/Explosion     0.0      0.0
#
#                                                    Target  \
# 132768                           Trucker: Pradeep Dungana
# 132796                           Civilian: Devendra Modem
# 132830                           Shoe Trader: Fozal Haque
# 132873                                            Unknown
# 132879  Civilians: Dubraj Manki, Nagi Manki, Surya Hansda
# ...                                                   ...
# 181663                       Koothuparamba Police Station
# 181665                             Road Construction Site
# 181672                                               Camp
# 181684  Personal Security Officer of Council Member Ih...
# 181689                                             Office
#
#                                                   Summary  \
# 132768  06/01/2014: Assailants kidnapped a truck drive...
# 132796  06/01/2014: Assailants attacked a civilian in ...
# 132830  06/02/2014: Assailants kidnapped a trader from...
# 132873  06/03/2014: An explosive device was discovered...
# 132879  06/03/2014: Assailants shot and killed three v...
# ...                                                   ...
# 181663  12/30/2017: Assailants threw an explosive devi...
# 181665  12/30/2017: Assailants set fire to seven vehic...
# 181672  12/31/2017: Assailants armed with grenades and...
# 181684  12/31/2017: Assailants abducted Prafulla Phuka...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
#
#                                                  Group  \
# 132768                   Kuki Revolutionary Army (KRA)
# 132796                                         Maoists
# 132830                   Garo National Liberation Army
# 132873                                         Unknown
# 132879                                         Maoists
# ...                                                ...
# 181663                                         Unknown
# 181665  Communist Party of India - Maoist (CPI-Maoist)
# 181672                          Jaish-e-Mohammad (JeM)
# 181684                        Zeliangrong United Front
# 181689                                         Unknown
#
#                         Target_type Weapon_type
# 132768  Private Citizens & Property    Firearms
# 132796  Private Citizens & Property       Melee
# 132830  Private Citizens & Property    Firearms
# 132873                      Unknown  Explosives
# 132879  Private Citizens & Property    Firearms
# ...                             ...         ...
# 181663                       Police  Explosives
# 181665                     Business    Firearms
# 181672                       Police  Explosives
# 181684         Government (General)    Firearms
# 181689         Government (General)  Explosives
#
# [2101 rows x 17 columns]

# %%
len(df)
# Out:
# 2101

# %% [markdown]
# Most Deadliest attack in a history of HumanKind?
#
# Print count of Killed people as integer value.
#
# Note: Here Deadliest attack means, in which the most number of people killed.

# %%
df = pd.read_csv(r"data set\\terrorismData.csv")
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# 0     1.0      0.0             Julio Guzman     NaN
# 1     0.0      0.0  Nadine Chaval, daughter     NaN
# 2     1.0      0.0                 Employee     NaN
# 3     NaN      NaN             U.S. Embassy     NaN
# 4     NaN      NaN           U.S. Consulate     NaN
#
#                                 Group                  Target_type Weapon_type
# 0                              MANO-D  Private Citizens & Property     Unknown
# 1  23rd of September Communist League      Government (Diplomatic)     Unknown
# 2                             Unknown          Journalists & Media     Unknown
# 3                             Unknown      Government (Diplomatic)  Explosives
# 4                             Unknown      Government (Diplomatic)  Incendiary

# %%
df.dropna()
# Out:
#         Year  Month  Day        Country            State  \
# 5       1970      1    1  United States         Illinois
# 7       1970      1    2  United States       California
# 8       1970      1    2  United States        Wisconsin
# 9       1970      1    3  United States        Wisconsin
# 11      1970      1    6  United States         Colorado
# ...      ...    ...  ...            ...              ...
# 181686  2017     12   31        Somalia  Middle Shebelle
# 181687  2017     12   31          Syria         Lattakia
# 181688  2017     12   31    Philippines      Maguindanao
# 181689  2017     12   31          India          Manipur
# 181690  2017     12   31    Philippines      Maguindanao
#
#                             Region           City   Latitude   Longitude  \
# 5                    North America          Cairo  37.005105  -89.176269
# 7                    North America        Oakland  37.791927 -122.225906
# 8                    North America        Madison  43.076592  -89.412488
# 9                    North America        Madison  43.072950  -89.386694
# 11                   North America         Denver  39.758968 -104.876305
# ...                            ...            ...        ...         ...
# 181686          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687  Middle East & North Africa         Jableh  35.407278   35.942679
# 181688              Southeast Asia       Kubentog   6.900742  124.437908
# 181689                  South Asia         Imphal  24.798346   93.940430
# 181690              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                             AttackType  Killed  Wounded  \
# 5                        Armed Assault     0.0      0.0
# 7                    Bombing/Explosion     0.0      0.0
# 8       Facility/Infrastructure Attack     0.0      0.0
# 9       Facility/Infrastructure Attack     0.0      0.0
# 11      Facility/Infrastructure Attack     0.0      0.0
# ...                                ...     ...      ...
# 181686                   Armed Assault     1.0      2.0
# 181687               Bombing/Explosion     2.0      7.0
# 181688  Facility/Infrastructure Attack     0.0      0.0
# 181689               Bombing/Explosion     0.0      0.0
# 181690               Bombing/Explosion     0.0      0.0
#
#                                                    Target  \
# 5                               Cairo Police Headquarters
# 7                                         Edes Substation
# 8       R.O.T.C. offices at University of Wisconsin, M...
# 9       Selective Service Headquarters in Madison Wisc...
# 11               Army Recruiting Station, Denver Colorado
# ...                                                   ...
# 181686                                         Checkpoint
# 181687                                   Hmeymim Air Base
# 181688                                             Houses
# 181689                                             Office
# 181690                                            Unknown
#
#                                                   Summary  \
# 5       1/1/1970: Unknown African American assailants ...
# 7       1/2/1970: Unknown perpetrators detonated explo...
# 8       1/2/1970: Karl Armstrong, a member of the New ...
# 9       1/3/1970: Karl Armstrong, a member of the New ...
# 11      1/6/1970: Unknown perpetrators threw a Molotov...
# ...                                                   ...
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                                              Group  \
# 5                               Black Nationalists
# 7                                          Unknown
# 8                                  New Year's Gang
# 9                                  New Year's Gang
# 11                             Left-Wing Militants
# ...                                            ...
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                         Target_type Weapon_type
# 5                            Police    Firearms
# 7                         Utilities  Explosives
# 8                          Military  Incendiary
# 9              Government (General)  Incendiary
# 11                         Military  Incendiary
# ...                             ...         ...
# 181686                     Military    Firearms
# 181687                     Military  Explosives
# 181688  Private Citizens & Property  Incendiary
# 181689         Government (General)  Explosives
# 181690                      Unknown  Explosives
#
# [105572 rows x 17 columns]

# %%
a =df.Killed.max()
a
# Out:
# 1570.0

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# 75%    6.871033e+01       2.000000       2.000000
# max    1.793667e+02    1570.000000    8191.000000

# %%
df= df[df.Killed == 1570]

# %%
df
# Out:
#         Year  Month  Day Country    State                      Region    City  \
# 133518  2014      6   12    Iraq  Saladin  Middle East & North Africa  Tikrit
#
#          Latitude  Longitude                   AttackType  Killed  Wounded  \
# 133518  34.621521  43.668377  Hostage Taking (Kidnapping)  1570.0      NaN
#
#           Target                                            Summary  \
# 133518  Soldiers  06/12/2014: Assailants abducted approximately ...
#
#                                               Group Target_type Weapon_type
# 133518  Islamic State of Iraq and the Levant (ISIL)    Military    Firearms

# %%
print(int(a), *df.Country, *df.Group)
# Out:
# 1570 Iraq Islamic State of Iraq and the Levant (ISIL)
